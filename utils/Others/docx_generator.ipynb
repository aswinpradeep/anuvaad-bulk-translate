# %%
import json
import docx
from docx.shared import Pt
from docx.shared import RGBColor
import os
from docx.enum.text import WD_BREAK

# %%
#delete existing output_doc.docx
try:
    os.remove("./output_doc.docx")
except:
    print("No file to be deleted")
    
#Read fetch_content
fetch_content_file = "./fetch_content.json"
with open(fetch_content_file,"r") as file:
    fetch_content = file.read()

fetch_content = json.loads(fetch_content)

#Read common info
page_height = fetch_content["data"][0]["page_height"]
page_width = fetch_content["data"][0]["page_width"]

#Create a document
document = docx.Document()

"""
Things to Consider for later on
Background Images
Lines
""" 

"""
"s0_src": "Input"
"s0_tgt": "TMX / UTM Output if it exists otherwise NMT Output"
"src": "Input"
"tgt": "TMX / UTM Output if it exists otherwise NMT Output"
"tagged_src": "Input"
"tagged_tgt": "NMT Output"
"""
# Out:
# '\n"s0_src": "Input"\n"s0_tgt": "TMX / UTM Output if it exists otherwise NMT Output"\n"src": "Input"\n"tgt": "TMX / UTM Output if it exists otherwise NMT Output"\n"tagged_src": "Input"\n"tagged_tgt": "NMT Output"\n'

# %%
def hex_to_rgb(hex_color):
    # Remove the '#' symbol if present
    hex_color = hex_color.lstrip('#')
    # Convert the hexadecimal string to RGB values
    return tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))

# %%
def add_text_with_position(doc, page_height, page_width, text_top, text_left, text, font_color, font_attrib, font_family, font_size, text_width):
    if text == "None" and font_size == None:
        return doc
    # Calculate the Y-coordinate based on page height and text top
    y = page_height - text_top
    
    # Create a paragraph for the text
    p = doc.add_paragraph()
    

    #Check if Bold / Italic attribute is present
    if font_attrib is not None:
        if "BOLD" in font_attrib:
            p.bold = True
        if "ITALIC" in font_attrib:
            p.italic = True

    # Calculate the number of spaces needed before the text
    # font_size = 11
    if font_size == None:
        font_size = 11
    # else:
    #     font_size = int(font_size*0.8)
    spacing_factor = 7.5 * (font_size / 12)  # Adjust 12 to your reference font size
    num_spaces = int(text_left / spacing_factor)
    spaces = " " * num_spaces

    p.style.font.size = Pt(font_size)            
    p.style.font.name = "Tiro Devanagari Hindi"
  
    # Add the spaces and text to the paragraph
    p.add_run(spaces + text)

    # Convert the hexadecimal font color to RGBColor
    if font_color is not None:
        font_color_rgb = RGBColor(*hex_to_rgb(font_color))
    else:
        font_color_rgb = RGBColor(*hex_to_rgb("#000000"))
    print(font_color)
    print(font_color_rgb)        #font_color_rgb = "000000"
    print(type(font_color))
    print(type(font_color_rgb))
    
    # Set font properties
    for run in p.runs:
        run.font.color.rgb = font_color_rgb  # RGB color

    # Set font properties

    # Calculate the text width and set a tab stop for the entire paragraph
    tab_stop_position = Pt(text_left + text_width)
    p.paragraph_format.tab_stops.add_tab_stop(tab_stop_position)
        
    # Set the vertical alignment of the paragraph
    p.alignment = 3  # 3 corresponds to centered alignment
    
    return doc

# %%
def func(block):
    return block["text_top"]


for block in fetch_content["data"]:
    text_blocks = block["text_blocks"].copy()
    text_blocks.sort(key=func)
    merged_text_blocks = []

    i=0
    while i<len(text_blocks):
        current_block = text_blocks[i]
        merged_block = current_block.copy()
        # Check if there are subsequent blocks with the same 'text_left'
        while i + 1 < len(text_blocks) and text_blocks[i]["text_left"] == text_blocks[i + 1]["text_left"]:
            spacing_factor = 7.5 * (11 / 12)  # Adjust 12 to your reference font size
            num_spaces = int(text_blocks[i+1]["text_left"]-text_blocks[i+1]["text_left"]/ spacing_factor)
            current_text = [token["s0_tgt"] for token in text_blocks[i]["tokenized_sentences"]]
            next_text = [token["s0_tgt"] for token in text_blocks[i+1]["tokenized_sentences"]]
            current_text = " ".join(current_text)
            next_text = " ".join(next_text)
            merged_block["merged_text"] = current_text + " "*num_spaces + next_text  # Merge text
            # You can also merge other properties if needed
            i += 1

        merged_text_blocks.append(merged_block)
        i += 1


    for each_block in merged_text_blocks:
        #Get block info
        font_attrib = each_block["attrib"]
        font_color = each_block["font_color"]
        font_family = each_block["font_family"]
        font_size = each_block["font_size"]
        text_height = each_block["text_height"]
        text_left = each_block["text_left"]
        text_top = each_block["text_top"]
        text_width = each_block["text_width"]
        if "merged_text" in each_block.keys():
            text = each_block["merged_text"]
        else:
            text = [token["s0_tgt"] for token in each_block["tokenized_sentences"]]
            text = " ".join(text)
        print(text)
        add_text_with_position(document,page_height,page_width,text_top,text_left, text,
                            font_color,font_attrib, font_family, font_size, text_width)
        #break
    p = document.add_paragraph()
    run = p.add_run()
    run.add_break(WD_BREAK.PAGE)
document.save("output_doc.docx")
# Out:
# 5 एस. सी. आर. सर्वोच्च न्यायालय की रिपोर्ट 37
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# जमुना सिंह और अन्य
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# वी.
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# BHADAI SAH
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# (बी. पी. सिन्हा, सी. जे., एम. हृदयतुल्ला और के. सी. दास)
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# गुप्ता जे. जे)
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# आपराधिक मुकदमा-किसी शिकायत पर अपराध का संज्ञान, जब लिया जाता है-संहिता के अध्याय XVI के प्रावधानों के तहत मजिस्ट्रेट कार्यवाही, यदि संज्ञान लेने के बराबर है-धाराओं के तहत शिकायतकर्ता द्वारा बरी किए जाने के खिलाफ अपील। 417 (3) दंड प्रक्रिया संहिता, 1898 (1898 का 5), ss.190 (1), 200-204 और 417 (3) का स्वामित्व।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# प्रत्यर्थी ने उप-मंडल मजिस्ट्रेट के समक्ष शिकायत दर्ज कराई कि अपीलकर्ताओं ने उन पर लाठियों से हमला किया
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# और दंड प्रक्रिया संहिता के s.200 के तहत परीक्षा पूरी करने के बाद उसके pocket.After से जबरन मुद्रा नोट ले गए, मजिस्ट्रेट ने निम्नलिखित आदेश दिया "एस. ए. पर शिकायत की जांच की। 12.12.56 द्वारा मामला दर्ज करने और रिपोर्ट करने के लिए अपराध संज्ञेय one.To S. I. बैकुंथपुर है। अल्टी।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 1.
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# विशेष रूप से, पुलिस द्वारा एक आरोप पत्र प्रस्तुत किया गया था और अपीलकर्ताओं को सत्र न्यायालय में प्रस्तुत किया गया था, लेकिन मुकदमा दंड प्रक्रिया संहिता की धारा 1 (3) के तहत प्रतिवादी द्वारा बरी करने की अपील में समाप्त हो गया, बरी करने के आदेश को उच्च न्यायालय द्वारा दरकिनार कर दिया गया था और अपीलकर्ताओं को दंड संहिता की धारा 3 के तहत दोषी ठहराया गया था और दो साल की कठोर सजा सुनाई गई थी।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# आयोजित किया गयाः (i) जब उसके समक्ष दायर की जा रही शिकायत की याचिका पर एक मजिस्ट्रेट दंड प्रक्रिया संहिता के अध्याय XVI के विभिन्न प्रावधानों के तहत कार्यवाही के लिए अपना दिमाग लगाता है, तो उसे अपराधों का संज्ञान लेने के लिए माना जाना चाहिए, हालांकि वह अपने दिमाग को ऐसे उद्देश्य के लिए नहीं बल्कि s.156 (3) के तहत जांच का आदेश देने या जांच के उद्देश्य से तलाशी वारंट जारी करने के उद्देश्यों के लिए लगाता है, यह नहीं कहा जा सकता है कि उसने किसी भी अपराध का संज्ञान लिया है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उत्तर प्रदेश के आर. आर. चारी v.State, [1951] एस. सी. आर. 312 और असम के गोपाल दास v.State, ए. आई. आर. 1961 एस. सी. 986 ने आवेदन किया।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# वर्तमान मामले में, जैसा कि इस तथ्य से स्पष्ट है कि मजिस्ट्रेट ने आपराधिक प्रो संहिता के s.200 के तहत कार्रवाई की
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# यह शर्त कि उसने शिकायत में उल्लिखित अपराधों का संज्ञान लिया था, उसके लिए केवल जांच का आदेश देने के लिए खुला था
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# s.202 के तहत और आपराधिक प्रो cedure.Therefore संहिता के s.156 (3) के तहत नहीं, यह अभिनिर्धारित किया जाना चाहिए कि हालांकि मजिस्ट्रेट                                                                                                                                    अपने आदेश में "एक मामला स्थापित करने के लिए" शब्दों का उपयोग करते हुए वह वास्तव में संहिता के s.202 के तहत कार्रवाई कर रहा था, जो कि एकमात्र section.under था जिसे वह कानून में कार्य करने का हकदार था।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# महादेव वी, शांतिभाई (मित्तर, जे.)
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 431.
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# विश्वविद्यालय का अधिनियम और Government.There का नहीं, इस बारे में संदेह की गुंजाइश है कि क्या ऊपर उल्लिखित परिस्थितियों में               अपीलकर्ता माधव महाविद्यालय में विधि व्याख्याता के रूप में सरकार के अधीन लाभ का पद इस तथ्य के कारण धारण कर रहा था कि चुनाव याचिका दायर करने के बाद तक सरकार या विश्वविद्यालय द्वारा उसके संबंध में किसी भी समय कोई आदेश पारित नहीं किया गया था।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अयोग्यता का अंतिम बिंदु यह था कि क्या
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अपीलकर्ता को उज्जैन में इम्प्रूवमेंट ट्रस्ट ट्रिब्यूनल के अध्यक्ष के रूप में उनकी नियुक्ति के कारण प्रो फिट पद का धारक कहा जा सकता है, अक्टूबर 1966 में इस आशय की एक अधिसूचना द्वारा राजपत्रित किया गया था कि राज्य सरकार को उज्जैन में भूमि अधिग्रहण के लिए मध्य प्रदेश आई. एम. प्रूवमेंट ट्रस्ट अधिनियम, 1960 की धारा 73 के उद्देश्य से नीचे निर्दिष्ट न्यायाधिकरण का गठन करने पर प्रसन्नता हुई थी।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# राष्ट्रपति
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# श्री एम. सी. जोशी, अधिवक्ता, उज्जैन।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# मूल्यांकनकर्ता।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 1. श्री चंद नारायण राजदान,
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सेवानिवृत्त यातायात अधीक्षक
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# आगर लाइट रेलवे उज्जैन।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उच्च न्यायालय ने अपने फैसले में कहा कि इस बात का कोई स्पष्ट सकारात्मक संकेत नहीं है कि अपीलकर्ता से पहले परामर्श किया गया था, निश्चित रूप से इस बात का कोई सबूत नहीं है कि उसने नियुक्ति पर कार्रवाई की थी या उसने कभी उच्च न्यायालय के निष्कर्ष का प्रभार संभाला था कि जब आदेश उसके घर पर दिया गया था, तो अपीलकर्ता ने इसे लिया और ट्रस्ट से जुड़े किसी भी व्यक्ति को सूचित नहीं किया, या उस मामले के लिए, सरकार को, कि आदेश गलती से उसके पास आ गया था और वह "एम. सी. जोशी" नहीं था जैसा कि उच्च न्यायालय ने "आई. डी. 1" में उल्लेख किया है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अपीलकर्ता इस कथित आई. डी. 1 पर "संदेह का लाभ" बताता है जो गलती के संबंध में काफी अलग है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# नाम, यह मानना मुश्किल है कि अपीलकर्ता ने लाभ का पद धारण किया था क्योंकि Tribunal.As के अध्यक्ष ने पहले ही उल्लेख किया था, कि उन्हें इस उद्देश्य के लिए कभी संपर्क नहीं किया गया था और न ही उन्होंने कभी notification.He की शर्तों के तहत कार्य करने की अपनी इच्छा का संकेत दिया था, उन्होंने कभी भी किसी पद का प्रभार नहीं लिया था और न ही उन्होंने कभी office.In परिस्थितियों के संबंध में किसी कार्य का निर्वहन किया था।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# यह मानना शायद ही सही होगा कि वह एक पद धारण कर रहा था                         Government.On के तहत लाभ इससे पहले की सामग्री
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उच्च न्यायालय यह अभिनिर्धारित करने के लिए तैयार नहीं था कि अपीलकर्ता
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# लाभ के पद के धारक और इस मामले के तथ्यों पर, हम करते हैं                           उच्च न्यायालय के निर्णय में बाधा डालने के लिए प्रेरित महसूस नहीं करना,
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# नतीजतन, अपील विफल हो जाती है और लागत के साथ खारिज कर दी जाती है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# R.K.P.S।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# याचिका खारिज कर दी गई।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# [1964]
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सर्वोच्च न्यायालय की रिपोर्ट
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 38
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# मजिस्ट्रेट द्वारा पहले ही संज्ञान लिया जा चुका है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# आदेश देने से पहले उसी अपराध का नए सिरे से संज्ञान लेने की कोई गुंजाइश नहीं थी क्योंकि पुलिस अधिकारियों की रिपोर्ट received.Thus थी और मामला शिकायत पर दर्ज किया गया था न कि later.The प्रस्तुत पुलिस रिपोर्ट पर इसलिए कि अपील s.417 (3) के तहत नहीं थी, खारिज की जानी चाहिए।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# (ii) मजिस्ट्रेट का आदेश पुलिस को संस्थान बनाने के लिए कहता है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# एक मामला और एक रिपोर्ट भेजने के लिए उचित रूप से और यथोचित रूप से दंड संहिता के Procedure.So के s.202 के तहत किए गए एक के रूप में पढ़ा जाना चाहिए, यह तर्क कि उसने अधिकार क्षेत्र के बिना काम किया, accepted.At नहीं हो सकता है, यह कहा जा सकता है कि जहां तक उसने पुलिस को एक मामला स्थापित करने के लिए कहा, उसने अनियमित रूप से काम किया, लेकिन यह सोचने का कोई कारण नहीं है कि इसके परिणामस्वरूप न्याय की विफलता हुई है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# आपराधिक अपील क्षेत्राधिकार अपराधी
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 1960 की अपील सं. 56।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# निर्णय से विशेष अनुमति द्वारा अपील और
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 1957 की आपराधिक अपील संख्या 63 में पटना उच्च न्यायालय का 27 नवंबर, 1959 का आदेश।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अपीलार्थियों के लिए डी. पी. सिंह।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# के. के. सिन्हा, प्रत्यर्थी के लिए।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 4 अक्टूबर, 1963। न्यायालय का निर्णय था
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# द्वारा वितरित किया गया
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# जे. दास गुप्ता-इन सात अपीलार्थियों पर मुकदमा चलाया गया।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सहायक सत्र न्यायाधीश, सरन द्वारा, भारतीय दंड संहिता के s.395 के तहत और भारतीय दंड संहिता के s.323 के तहत भी आरोपों पर, लेकिन उन्हें दोनों आरोपों से बरी कर दिया गया।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अभियोजन पक्ष का मामला था कि 15 नवंबर को,
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 1956 में जब बैकुंथपुर के पुलिस थाने के भीतर तियोतिथ के एक व्यवसायी भदाई साह पटुआ खरीदने के लिए गांव की सड़क से गुजर रहे थे, तो लाठियों से लैस सात अपीलकर्ताओं ने उन्हें घेर लिया और मांग की कि उन्हें पटाखे सौंप देने चाहिए।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# him.Bhadai के साथ उसके पास जो धन था, उसके पास Rs.250 था, लेकिन उसने them.Kesho के साथ भाग लेने से इनकार कर दिया, अपीलकर्ताओं में से एक ने उसकी जेब से जबरन मुद्रा नोट छीनने की कोशिश की, लेकिन भदाई ने पकड़ लिया।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उसके pocket.Bhadai से एक याचिका दायर की गई                  22 नवंबर, 1956 को उप-मंडल मजिस्ट्रेट, गोपालगंज के न्यायालय में शिकायत की।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सर्वोच्च न्यायालय की रिपोर्ट 39
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 5 एससीआर।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# गंभीर अफर्मा पर उससे पूछताछ करने के बाद मजिस्ट्रेट
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# राष्ट्र ने एक आदेश दिया जिसमें बैकुंथपुर के पुलिस उपनिरीक्षक को 12 दिसंबर, 1956 तक एक मामला दर्ज करने और रिपोर्ट देने के लिए कहा गया। अंततः, पुलिस द्वारा एक आरोप-पत्र प्रस्तुत किया गया और अभियुक्त व्यक्तियों को सत्र न्यायालय के समक्ष प्रस्तुत किया गया और सभी अपीलार्थियों को बरी कर दिया गया, जैसा कि पहले ही कहा जा चुका है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# बरी किए जाने के आदेश के खिलाफ, भदाई साह ने उच्च न्यायालय में दंड प्रक्रिया संहिता के s.417 (3) के तहत Patna.On पर अपील दायर की, अगले दिन उच्च न्यायालय के दो विद्वान न्यायाधीशों ने आदेश दियाः अपील की सुनवाई की जाएगी। "इसके बाद अपील दो लोगों के सामने सुनवाई के लिए आई।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# जालान
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# न्यायालय के अन्य विद्वान न्यायाधीशों की राय है कि विद्वान सत्र न्यायाधीश ने साक्ष्य की विश्वसनीयता का आकलन करने के लिए किसी भी वास्तविक प्रयास के बिना अनुचित मानकों पर प्रतिभूति साक्ष्य को खारिज कर दिया था और अभियोजन पक्ष का मामला पूरी तरह से स्थापित था
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# साक्ष्य द्वारा, बरी करने के आदेश को दरकिनार कर दिया और अपीलार्थियों को भारतीय दंड संहिता के s.395 के तहत दोषी ठहराया और उन्हें दो साल के कठोर कारावास की सजा सुनाई।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उच्च न्यायालय के इस आदेश के खिलाफ वर्तमान अपील इस न्यायालय की विशेष अनुमति से दायर की गई है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अपील के समर्थन में आग्रह किया गया मुख्य तर्क यह है कि इस मामले में दंड संहिता के s.417 (3) के तहत बरी होने के आदेश के खिलाफ उच्च न्यायालय में कोई अपील नहीं है s.417 में प्रावधान को 1955 के संशोधन अधिनियम XXVI द्वारा संहिता में पेश किया गया था, जो एक शिकायतकर्ता को अधिकार देता है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# बरी किए जाने के विरुद्ध अपील जहां इस नए विधान पर कोई मामला दर्ज किया गया है, केवल राज्य सरकार को उप-धारा 3 में नए प्रावधान के परिणामस्वरूप बरी किए जाने के आदेश के विरुद्ध अपील करने का अधिकार था, वह यह है कि यदि बरी करने का आदेश पारित किया जाता है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उच्च न्यायालय के अलावा कोई अन्य न्यायालय किसी शिकायत पर स्थापित मामले में, उच्च न्यायालय इस ओर से शिकायतकर्ता द्वारा उसे किए गए आवेदन पर
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# बरी किए जाने के आदेश से अपील करने के लिए विशेष अनुमति प्रदान करें और शिकायतकर्ता को इस तरह की अनुमति दी जाए                                                                                                                                         उच्च Court.It 40 को ऐसी अपील प्रस्तुत कर सकते हैं
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
#
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सर्वोच्च न्यायालय की रिपोर्ट
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# [1964]
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# यह ध्यान दिया जाना चाहिए कि यह अधिकार केवल मामलों तक ही सीमित है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अपील की ओर से complaint.On पर स्थापित
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# यह तर्क दिया जाता है कि उनके खिलाफ मामला नहीं था
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# किसी भी शिकायत पर स्थापित किया गया था लेकिन इस पर स्थापित किया गया था
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# पुलिस रिपोर्ट।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# संहिता में इसकी कोई परिभाषा नहीं है -
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# शब्द "एक मामले की संस्था"। हालाँकि यह स्पष्ट है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# और वास्तव में विवादित नहीं है, कि एक मामले को कहा जा सकता है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# एक अदालत में केवल तभी स्थापित किया जाता है जब अदालत लेता है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# दंड प्रक्रिया संहिता के कथित therein.Section 190 (1) के संज्ञान में शामिल हैं
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# Magistrates.It द्वारा अपराधों के संज्ञान के लिए प्रावधान तीन तरीकों का प्रावधान करता है जिसमें इस तरह का संज्ञान taken.The हो सकता है पहला उन तथ्यों की शिकायत प्राप्त करने पर है जो इस तरह के अपराध का गठन करते हैं; दूसरा किसी भी पुलिस अधिकारी द्वारा बनाए गए ऐसे तथ्यों-यानी अपराध का गठन करने वाले तथ्यों-की लिखित रिपोर्ट पर है; तीसरा एक पुलिस अधिकारी के अलावा किसी अन्य व्यक्ति से प्राप्त जानकारी पर या मजिस्ट्रेट पर है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अपना ज्ञान या संदेह है कि इस तरह के अपराध                      committed.Section 193 संज्ञान के लिए प्रदान करता है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सत्र न्यायालयों द्वारा किए जा रहे अपराधों का
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# विधिवत सशक्त मजिस्ट्रेट द्वारा इसके प्रति वचनबद्धता                       इसमें behalf.Section 194 संज्ञान प्रदान करता है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# एक पर अपराधों के उच्च न्यायालय द्वारा लिया जा रहा है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# में दिए गए तरीके से इसके लिए की गई प्रतिबद्धता                       कोड।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# इन प्रावधानों की जांच से यह पता चलता है कि
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# स्पष्ट करें कि जब कोई मजिस्ट्रेट ऐसे तथ्यों की शिकायत प्राप्त करने पर किसी अपराध का संज्ञान लेता है जो ऐसे अपराध का गठन करते हैं, तो मजिस्ट्रेट के न्यायालय में एक मामला दर्ज किया जाता है और ऐसा मामला complaint.Again पर स्थापित किया जाता है, जब कोई मजिस्ट्रेट किसी पुलिस अधिकारी द्वारा दिए गए ऐसे तथ्यों की लिखित रिपोर्ट पर किसी अपराध का संज्ञान लेता है तो यह पुलिस रिपोर्ट पर मजिस्ट्रेट की अदालत में दर्ज किया गया मामला है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# यह तय करने के लिए कि क्या वह मामला जिसमें अपीलार्थी
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# पहले बरी किए गए और उसके बाद दोषी ठहराए गए
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# किसी शिकायत पर स्थापित किया गया या नहीं, यह पता लगाना आवश्यक है कि उप-मंडल मजिस्ट्रेट, गोपाल गंज, जिनके न्यायालय में मामला दर्ज किया गया था, ने 5 एस. सी. आर. लिए थे या नहीं।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
#
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सर्वोच्च न्यायालय की रिपोर्ट 41
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 22 नवंबर, 1956 को अपने न्यायालय में दायर भदाई साह की शिकायत पर या 13 दिसंबर, 1956 की पुलिस उपनिरीक्षक की रिपोर्ट पर विचाराधीन अपराधों का संज्ञान। अब यह अच्छी तरह से तय हो गया है कि जब एक मजिस्ट्रेट अपने समक्ष दायर की जा रही शिकायत की याचिका पर अध्याय XVI के विभिन्न प्रावधानों के तहत आगे बढ़ने के लिए अपना दिमाग लगाता है                                                                                                                                                                                  दंड प्रक्रिया संहिता के अनुसार, उसे यह माना जाना चाहिए कि उसने आई. डी. 2 में उल्लिखित अपराधों का संज्ञान लिया है, हालांकि वह इस तरह के उद्देश्य के लिए नहीं बल्कि आई. डी. 1 (3) के तहत जांच का आदेश देने या तलाशी जारी करने के उद्देश्यों के लिए अपना दिमाग लगाता है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# जाँचक उद्देश्य ओ
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# के लिए आदेश                                                                                                                                                                                    यह नहीं कहा जा सकता है कि आर. आर. चारी v.State में इस न्यायालय द्वारा किसी भी offence.It का संज्ञान लिया गया था।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उत्तर प्रदेश 1) और फिर असम के गोपाल दास v.State में (2)
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# हमारे समक्ष मामले में मजिस्ट्रेट भदाई साह की शिकायत प्राप्त होने के बाद आगे बढ़े
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# इन पाठ्यक्रमों में से कोई भी करने से पहले, आपराधिक संहिता की धारा Procedure.That के तहत कार्रवाई करने के लिए मजिस्ट्रेट को "शिकायत किए गए व्यक्तियों की उपस्थिति को मजबूर करने के लिए प्रक्रिया के मुद्दे को स्थगित करने का अधिकार है, और या तो स्वयं मामले की जांच करें या यदि वह तीसरे वर्ग के मजिस्ट्रेट के अलावा मजिस्ट्रेट है, तो किसी भी मजिस्ट्रेट द्वारा जांच या जांच करने का निर्देश दें।                                                                                                                                                                                  (1) [1951] एस. सी. आर. 312।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# (2) ए. आई. आर. (1961) एस. सी. 986।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सर्वोच्च न्यायालय की रिपोर्ट
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 42.
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# [1964]
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# शिकायत की सच्चाई या झूठ का पता लगाने के उद्देश्य से उसके अधीनस्थ, या किसी पुलिस अधिकारी द्वारा, या ऐसे अन्य व्यक्ति द्वारा जिसे वह उचित समझता है। "यदि और कब ऐसी जांच या जांच का आदेश दिया जाता है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# मजिस्ट्रेट द्वारा आपराधिक संहिता के s.203 के तहत कोई कार्रवाई करने से पहले जांच या जांच के परिणाम को ध्यान में रखा जाना चाहिए।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# प्रक्रिया।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# हम पाते हैं कि हमारे सामने मामले में मजिस्ट्रेट
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# s.200 के तहत परीक्षा पूरी करने के बाद
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# दंड प्रक्रिया संहिता और रिकॉर्डिंग
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# इसके सार ने इन शब्दों में क्रम बनायाः -
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# "एस. ए. पर शिकायत की जांच की। अपराध
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# में के लिए संज्ञेय one.To एस. आई. बैकुंथपुर है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# एक मामले को दर्ज करना और 12.12.56 द्वारा रिपोर्ट करना।                                                                                         अगर विद्वान मजिस्ट्रेट ने शब्दों का इस्तेमाल किया होता
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# "जांच के लिए" किसी मामले को स्थापित करने के लिए "शब्दों के बजाय" आदेश स्पष्ट रूप से आपराधिक संहिता के s.202 के तहत होगा Procedure.We यह मत सोचिए कि तथ्य यह है कि उन्होंने "मामला स्थापित करने के लिए" शब्दों का उपयोग किया है, इस पर ध्यान दिया जाना चाहिए कि मजिस्ट्रेट complaint.He की प्राप्ति पर अपराधों का संज्ञान लेने के लिए बाध्य नहीं था।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# बिना संज्ञान लिए निर्देशित किया जा सकता था                      हालाँकि पुलिस द्वारा आपराधिक संहिता Procedure.Once के s.156 (3) के तहत मामले की जाँच
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# उन्होंने संज्ञान लिया कि वह जांच का आदेश दे सकते हैं                     पुलिस द्वारा केवल दंड प्रक्रिया संहिता के s.202 के तहत और दंड संहिता Procedure.As के s.156 (3) के तहत नहीं, यह यहाँ से स्पष्ट है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# तथ्य यह है कि उसने दंड प्रक्रिया संहिता के s.200 के तहत कार्रवाई की, कि उसने शिकायत में उल्लिखित अपराधों का संज्ञान लिया था, यह उसके लिए खुला था कि वह केवल दंड प्रक्रिया संहिता के s.202 के तहत जांच का आदेश दे और Code.It के s.156 (3) के तहत नहीं, इन परिस्थितियों में यह अभिनिर्धारित करना उचित होगा कि हालांकि मजिस्ट्रेट
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 22 नवंबर, 1956 के इस आदेश में "एक मामला स्थापित करने के लिए" शब्दों का उपयोग किया गया था, वे वास्तव में दंड प्रक्रिया संहिता, 5 एस. सी. आर. के s.202 के तहत कार्रवाई कर रहे थे।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
#
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# कि एकमात्र धारा जिसके तहत वह कानून में कार्य करने का हकदार था।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# गठन रिपोर्ट और उसके खिलाफ "आरोप पत्र" प्रस्तुत किया                                                                                                                                                                                     अभियुक्त व्यक्ति 22 नवंबर, 1956 को मजिस्ट्रेट द्वारा पारित आदेश के बारे में हमारे द्वारा लिया गया कोई भी विचार नहीं बना सकते हैं, पुलिस अधिकारी द्वारा दी गई रिपोर्ट हालांकि दंड प्रक्रिया संहिता के तहत एक रिपोर्ट होने का तात्पर्य है, इसे कानून में एक रिपोर्ट माना जाना चाहिए।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# केवल दंड प्रक्रिया संहिता के s.202 के तहत।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# संहिता के s.190 के प्रावधानों पर भरोसा करते हुए कि मजिस्ट्रेट द्वारा संज्ञान लिया जा सकता है
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# पुलिस अधिकारी की रिपोर्ट पर अपीलार्थियों के विद्वान वकील ने तर्क दिया कि जब मजिस्ट्रेट ने 22 नवंबर, 1956 को आदेश दिया था तो उनका इरादा था कि वह पुलिस अधिकारी की रिपोर्ट प्राप्त होने के बाद ही संज्ञान लेंगे और यह संज्ञान 13 दिसंबर, 1956 के बाद संहिता के s.173 के तहत आरोप पत्र के रूप में प्राप्त होने के बाद ही लिया जाना चाहिए। हालाँकि, इस तर्क के रास्ते में अपूरणीय कठिनाई यह है कि मजिस्ट्रेट ने पहले ही आपराधिक संहिता की जाँच के तहत शिकायतकर्ता की जाँच इस आधार पर की थी कि उसने संज्ञान लिया था और इस कार्रवाई के बावजूद यह कहना संभव नहीं है कि जब उसने बैकुंथपुर के उप-निरीक्षक को मामला दर्ज करने और उनके द्वारा रिपोर्ट करने का आदेश दिया था, तब पहले से ही संज्ञान नहीं लिया गया था।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 12.12.56।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# मजिस्ट्रेट द्वारा आदेश देने से पहले ही संज्ञान लिए जाने के कारण पुलिस अधिकारी की रिपोर्ट received.There होने के बाद उसी अपराध का नए सिरे से संज्ञान लेने की कोई गुंजाइश नहीं थी, इसलिए निष्कर्ष से बचना संभव नहीं है।                                                                                                                                                                                            कि मामला 22 नवंबर, 1956 को भदाई साह की शिकायत पर दर्ज किया गया था, न कि पुलिस उप-निरीक्षक, बैकुन 44 द्वारा बाद में प्रस्तुत पुलिस रिपोर्ट पर।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
#
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# सर्वोच्च न्यायालय की रिपोर्ट [1964]
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# thpur.The यह तर्क कि अपील दंड प्रक्रिया संहिता के s.417 (3) के तहत नहीं है, इसलिए खारिज किया जाना चाहिए।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अपीलार्थियों की ओर से उठाया गया अगला तर्क यह है कि उच्च न्यायालय में न्यायसंगत नहीं था
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# विद्वान सहायक सत्रों द्वारा बरी किए जाने के आदेश में हस्तक्षेप करना, जिसके कारण पर विद्वान सहायक सत्र न्यायाधीश ने अभियोजन पक्ष के गवाहों के साक्ष्य को खारिज कर दिया और जिन कारणों से उच्च न्यायालय के विद्वान न्यायाधीशों की राय थी कि विद्वान सत्र न्यायाधीश द्वारा साक्ष्य की विश्वसनीयता का आकलन करने के लिए कोई वास्तविक प्रयास नहीं किया गया था, यह स्पष्ट है कि उच्च न्यायालय ने मामले की पूरी तरह से और सावधानी से जांच की और साक्ष्य पर विस्तृत विचार करने पर यह निष्कर्ष निकला कि साक्ष्य के मूल्यांकन के परिणामस्वरूप इस न्यायालय द्वारा मामलों की एक श्रृंखला में निर्धारित किए गए सिद्धांतों की गंभीर विफलता हुई थी क्योंकि उच्च न्यायालय द्वारा बरी किए जाने के आदेशों के साथ अंतर-निष्पक्षता के संबंध में उच्च न्यायालय द्वारा सही ढंग से पालन किया गया है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# अंतिम उपाय के रूप में अपीलार्थियों के विद्वान वकील ने तर्क दिया कि मजिस्ट्रेट ने पुलिस को मामला दर्ज करने के लिए कहने में अधिकार क्षेत्र के बिना काम किया था और इसलिए उस आदेश के बाद की कार्यवाही सभी void.As थी, हम पहले ही इंगित कर चुके हैं, मजिस्ट्रेट के आदेश में पुलिस को एक मामला दर्ज करने और एक रिपोर्ट भेजने के लिए कहा गया है, जिसे ठीक से और यथोचित रूप से आपराधिक संहिता <ID2 के s.202 के तहत किया गया है, यह तर्क कि विद्वान मजिस्ट्रेट ने न्यायशास्त्र की भाषा के बिना काम किया, accepted.At नहीं हो सकता है, यह कहा जा सकता है कि जहां तक विद्वान मजिस्ट्रेट ने पुलिस को एक मामला दर्ज करने के लिए कहा है, उसने irregularly.There किया, तो यह सोचने का कोई कारण नहीं है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
#
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# 5 एससीआर।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# कि उस अनियमितता के परिणामस्वरूप उच्च न्यायालय द्वारा पारित दोषसिद्धि और सजा के justice.The आदेश की किसी भी विफलता को उस अनियमितता के कारण उलट या बदला नहीं जा सकता है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# नतीजतन, अपील खारिज कर दी जाती है।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# याचिका खारिज कर दी गई।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# प्रबीत्र कुमार बनर्जी
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# वी.
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# पश्चिम बंगाल राज्य
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# (बी. पी. सिन्हा, सी. जे., पी. बी. गजेन्द्रगडकर, के. एन.
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# वांचू, एम. हिदायतुल्ला और जे. सी. शाह जे.)
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# भारत का संविधान, Art.14-कलकत्ता उच्च न्यायालय (मूल पक्ष) बार-वर्गीकरण ने अभिवचन और कार्य-विभिन्न वर्गों के लिए अलग आवास-यदि कानून के समक्ष समानता से इनकार करने के बराबर है।                     कलकत्ता उच्च न्यायालय ने अदालत परिसर में बैरिस्टरों को उनके बार लाइब्रेरी क्लब के लिए उपयोग और व्यवसाय के लिए, उनके बार एसोसिएशन के बैरिस्टरों के अलावा अन्य अधिवक्ताओं और उनके निगमित कानून याचिकाकर्ताओं के लिए अटॉर्नी को अलग से कमरे आवंटित किए थे, जो कलकत्ता उच्च न्यायालय के अधिवक्ता थे और आम तौर पर इसके मूल पर वकालत करते थे।
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
# पक्ष और जिन्हें अंग्रेजी बार में बुलाया गया था, उन्होंने मूल पक्ष के नियमों के अनुसार इंग्लैंड या कलकत्ता में एक अभ्यास करने वाले बैरिस्टर के चैंबर में 12 महीने की अवधि के लिए नहीं पढ़ा था, लेकिन बार लाइब्रेरी क्लब का सदस्य बनने के लिए आवेदन किया था और उनके आवेदन थे कि मुख्य न्यायाधीश के लिए प्रतिनिधित्व भी संविधान के Art.32 के तहत उनका आवेदन था, इस न्यायालय ने पश्चिम बंगाल राज्य के खिलाफ एक नियम जारी किया और बार लाइब्रेरी क्लब के मुख्य Justice.The संयुक्त सचिवों को बाद में पक्षों के रूप में जोड़ा गया और बार एसोसिएशन के इस हस्तक्षेप के परिणामस्वरूप बार एसोसीएशन ने कहा कि याचिका जो मूल रूप से थी वह बार लाइब्रेरी की विशिष्टता को समाप्त करने के दावे में ब्रोडेन्ड थी
# #000000
# 000000
# <class 'str'>
# <class 'docx.shared.RGBColor'>
